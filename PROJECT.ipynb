# %% [markdown]
# ## ERIRIE JEFFREY

# %% [markdown]
# ## ID: 11116737

# %% [markdown]
# ## DEPARTMENT: COMPUTER ENGINEERING

# %% [markdown]
# ## ABOUT THIS PROJECT

# %% [markdown]
# ><br>
# The goal of this project is to perform exploratory data analysis on a modified version of the redwine dataset.The  Red Wine Quality Analysis dataset contains 12 input variables, including fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, and alcohol, with the output variable being the quality score between 0 and 10. It is a multivariate dataset with 1599 observations and is sourced from the UCI Machine Learning Repository.The aim of this project is to gain insights into the factors that contribute to the quality of red wine and to identify potential predictors of high-quality wine. This project can be useful for individuals in the wine industry, including vintners and wine producers, as well as data scientists and analysts seeking to explore the potential for data modeling in this domain.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mat
import seaborn

# %% [markdown]
# ## Loading  the redwine dataset.

# %%
# Importing the red wine dataset.NB:it must be in the same directory as the running notebook.
wineData = pd.read_csv('red_wine.csv')
wineData
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## Exploration of the wineDataset.

# %%
wineData.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wineData.columns = wineData.columns.str.replace(" ","_")

# %%
wineData.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
wineData.tail(20)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
wineData.shape
# Out:
# (1599, 12)

# %%
wineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1598 non-null   float64
#  1   volatile_acidity      1598 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free_sulfur_dioxide   1598 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# ### Description of wine data.

# %%
Statistics = wineData.describe()
Statistics
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# ### Cleaning the wineDataset.

# %%
wineData.isnull().sum()
# Out:
# fixed_acidity           1
# volatile_acidity        1
# citric_acid             0
# residual_sugar          0
# chlorides               4
# free_sulfur_dioxide     1
# total_sulfur_dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
mean_fixed_acidity = Statistics.fixed_acidity.loc['mean']
mean_volatile_acidity = Statistics.volatile_acidity.loc['mean']
mean_chlorides = Statistics.chlorides.loc['mean']
mean_free_sulfur_dioxide = Statistics.free_sulfur_dioxide.loc['mean']
mean_density = Statistics.density.loc['mean']
mean_quality = Statistics.quality.loc['mean']

# %%
cleanedWineData = wineData.copy()

# %%
cleanedWineData.fixed_acidity = cleanedWineData.fixed_acidity.fillna(mean_fixed_acidity)
cleanedWineData.volatile_acidity = cleanedWineData.volatile_acidity.fillna(mean_volatile_acidity)
cleanedWineData.chlorides = cleanedWineData.chlorides.fillna(mean_chlorides)
cleanedWineData.free_sulfur_dioxide = cleanedWineData.free_sulfur_dioxide.fillna(mean_free_sulfur_dioxide)
cleanedWineData.density =cleanedWineData.density.fillna(mean_density)
cleanedWineData.quality = cleanedWineData.quality.fillna(mean_quality)

# %%
cleanedWineData.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
cleanedWineData
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
cleanedWineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
cleanedWineData.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
# Eliminating duplicates.
cleanedWineData =cleanedWineData.drop_duplicates()
cleanedWineData
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# checking the data to ensure duplicates no longer exist
cleanedWineData.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 1593    False
# 1594    False
# 1595    False
# 1597    False
# 1598    False
# Length: 1360, dtype: bool

# %%
correlation = cleanedWineData.corr()
correlation
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.253679     0.666754
# volatile_acidity          -0.253679          1.000000    -0.550037
# citric_acid                0.666754         -0.550037     1.000000
# residual_sugar             0.110855         -0.002313     0.143677
# chlorides                  0.085835          0.054840     0.209866
# free_sulfur_dioxide       -0.139707         -0.020591    -0.047983
# total_sulfur_dioxide      -0.102660          0.072334     0.047944
# density                    0.669677          0.024102     0.359296
# pH                        -0.685521          0.247132    -0.548681
# sulphates                  0.190178         -0.256904     0.325422
# alcohol                   -0.061216         -0.197714     0.104459
# quality                    0.119190         -0.395077     0.226920
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
cleanedWineData_statistics = cleanedWineData.describe()
cleanedWineData_statistics
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1360.000000       1360.000000  1360.000000     1360.000000
# mean        8.310013          0.529443     0.272500        2.523235
# std         1.735778          0.182947     0.195562        1.351830
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1360.000000          1360.000000           1360.000000  1360.000000
# mean      0.088128            15.893285             46.843750     0.996710
# std       0.049351            10.443426             33.403084     0.001869
# ...

# %% [markdown]
# ## ANALYSIS OF THE CLEANED VERSION OF WINE DATA.

# %%
cleanedWineData.quality.value_counts()
# From the output below, it can be seen that a larger proportion of rediwnes scored a quality rating of 5 to 7.
# Out:
# quality
# 5.000000    578
# 6.000000    534
# 7.000000    167
# 4.000000     53
# 8.000000     17
# 3.000000     10
# 5.635795      1
# Name: count, dtype: int64

# %%
story = cleanedWineData.groupby('quality').mean()
story
# Out:
#           fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# 3.000000       8.360000          0.884500     0.171000        2.635000
# 4.000000       7.779245          0.693962     0.174151        2.694340
# 5.000000       8.170101          0.578633     0.244965        2.509170
# 5.635795       8.900000          0.220000     0.480000        1.800000
# 6.000000       8.336330          0.496382     0.278989        2.458521
# 7.000000       8.858683          0.403653     0.371856        2.716766
# 8.000000       8.441176          0.427647     0.382941        2.576471
#
#           chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# quality
# 3.000000   0.122500            11.000000             24.900000  0.997464
# 4.000000   0.090679            12.264151             36.245283  0.996542
# 5.000000   0.093956            17.158940             57.429931  0.997084
# 5.635795   0.077000            29.000000             60.000000  0.996800
# ...

# %% [markdown]
# ### Scatter PLOT

# %%
# %matplotlib inline

# %%
mat.figure(figsize = (10, 10))
mat.title('GRAPH OF ph Vs Acidity', fontdict = {'fontweight': 'bold'})
mat.scatter(x = 'pH', y = 'fixed_acidity', data = cleanedWineData, c = 'y', alpha = 0.8)
mat.xlabel('pH', fontsize = 12, fontstyle = 'italic')
mat.ylabel('Fixed acidity')
mat.legend()

# %% [markdown]
# #### INTERPRETATION OF THE SCATTER PLOT
# > In red wines, there is a clear negative correlation between pH and fixed acidity, where lower pH levels are associated with higher fixed acidity. Put simply, as the pH of red wine rises, its fixed acidity tends to decline, demonstrating an inverse relationship between these two factors in the dataset

# %% [markdown]
# ## Histogram
# Based on the density

# %%
# Using matplotlib for the histogram.
bins = np.arange(0.990, 1.004,0.002)

mat.figure(figsize = (8,7))
mat.hist(cleanedWineData.density, bins = bins, rwidth = 0.8, color='green')
mat.xticks(bins)

mat.title('Density of The Red Wines', fontdict = {'fontweight': 'bold'})
mat.xlabel('Density', fontsize=15, fontstyle='italic', c='r')
mat.ylabel('Red Wine', fontsize=15, fontstyle='italic', c='r')
                                                  
mat.show()

# %% [markdown]
# <p>From the histogram above, it can be observerd that most of the red wines had a density between the range 0.994 to 1.000.</p>

# %%
pd.DataFrame(cleanedWineData.alcohol.value_counts())
# Out:
#            count
# alcohol
# 9.500000     111
# 9.400000      91
# 9.200000      65
# 9.800000      63
# 10.000000     61
# ...          ...
# 8.500000       1
# 10.033333      1
# 13.500000      1
# 13.200000      1
# 10.750000      1
#
# [65 rows x 1 columns]

# %%
# Using matplotlib for the histogram.
bins = np.arange(8.5, 13.5, 0.5)

mat.figure(figsize = (8,7))
mat.hist(cleanedWineData.alcohol, bins = bins, rwidth = 0.8, color='yellow')
mat.xticks(bins)

mat.title('Alcohol content of The Red Wines', fontdict = {'fontweight': 'bold'})
mat.xlabel('Alcohol Content', fontsize=15, fontstyle='italic', c='r')
mat.ylabel('Red Wine', fontsize=15, fontstyle='italic', c='r')
                                                  
mat.show()

# %%
cleanedWineData['quality'].unique()
# Out:
# array([5.        , 6.        , 7.        , 4.        , 5.63579474,
#        8.        , 3.        ])

# %%
cleanedWineData_statistics[['residual_sugar', 'sulphates', 'alcohol', 'free_sulfur_dioxide', 'citric_acid', 'chlorides']].loc['mean']
# Out:
# residual_sugar          2.523235
# sulphates               0.658640
# alcohol                10.431777
# free_sulfur_dioxide    15.893285
# citric_acid             0.272500
# chlorides               0.088128
# Name: mean, dtype: float64

# %% [markdown]
# ## PIE CHART
# The sectors of this pie chart are the sulphates,alcohol,free sulphur dioxide,citric acid,chlorides and average amount of residual sugar from the wineDataSet.

# %%
ResidualSugar     = cleanedWineData_statistics['residual_sugar'].loc['mean']
Sulphates         = cleanedWineData_statistics['sulphates'].loc['mean']
Alcohol           = cleanedWineData_statistics['alcohol'].loc['mean']
FreeSulfurDioxide = cleanedWineData_statistics['free_sulfur_dioxide'].loc['mean']
CitricAcid        = cleanedWineData_statistics['citric_acid'].loc['mean']
Chlorides         = cleanedWineData_statistics['chlorides'].loc['mean']

labels = ['Residual sugar', 'Sulphates', 'Alcohol', 'Free sulfur dioxide', 'Citric acid', 'Chlorides']
Values = [0,0,0,0,0,0.6]

mat.pie([ResidualSugar, Sulphates, Alcohol, FreeSulfurDioxide, CitricAcid, Chlorides],
labels = labels, autopct = '%.2f %%', explode = Values)
mat.title('THE COMPONENT OF THE RED WINE', fontdict = {'fontweight' : 'bold'}, ha = 'center')
mat.show()

# %% [markdown]
# <b>INTERPRETING THE PIE CHART ABOVE <b> <br>
# The analysis of red wine quality utilized the mean quality of its various components to simplify the comparison, treating the components as if they belong to a single red wine. This approach was adopted to evaluate the percentage composition in red wine from an aggregated perspective. The goal was to assess the red wine's quality based on this collective view, despite the detailed individual qualities of different red wines. This method aimed to streamline the comparison of red wines by considering their components as a unified entity.

# %%
cleanedWineData.hist(figsize=(10,10),bins=50, color='orange')
mat.show()

# %%
# Evaluating the relationship between each input variable.
mat.figure(figsize=(30,30))
seaborn.heatmap(cleanedWineData.corr(), annot=True, cmap='Oranges')
mat.show()

# %% [markdown]
# ### INTERPRETATION OF THE HEATMAP ABOVE. <br>
# <b>From the correlation heatmap above, there are strong relationships between:</b>
# <ul>
#     <li> Alcohol and Quality </li>
#     <li> Fixed acidity and Citric acid </li>
#     <li> Total Sulphur dioxide and Free sulphur dioxide </li>
# </ul>

# %% [markdown]
# ### VISUALIZING THE RELATIONSHIP BETWEEN ALCOHOL AND WINE QUALITY.

# %%
seaborn.lineplot(y='alcohol', x='quality', data=cleanedWineData,color='red')
mat.xlabel('Quality')
mat.ylabel('Alcohol')
# Out:
# Text(0, 0.5, 'Alcohol')

# %% [markdown]
# <b>It can be observerd from the lineplot above that, the more alcohol wine contains, the higher it's quality rating.</b>
